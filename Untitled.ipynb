# %%
import numpy as np
import matplotlib.pyplot as plt
from readspectrum_combinedspec import readspectrum_combinedspec
spec_file = '54950.273831combined_spectra.fits'
(fspec, ferr, fend, fheader, fmjd) = readspectrum_combinedspec(spec_file);
wavend = fend*4.0 + 4000.0
wave = np.linspace(4000.0, wavend,fend);
# Out:
# 1 spectrum size

# %%
# %matplotlib nbagg
a=plt.plot(np.log10(wave),np.log10(fspec))
# Out:
# Warning: Cannot change to a different GUI toolkit: nbagg. Using notebook instead.
# <img src="data:image/png;base64,...">
