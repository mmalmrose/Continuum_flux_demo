# %%
import numpy as np
import matplotlib.pyplot as plt
from readspectrum_combinedspec import readspectrum_combinedspec
spec_files = '54950.273831combined_spectra.fits'
pol_files = ''
(fspec, ferr, fend, fheader, fmjd) = readspectrum_combinedspec(spec_file);
wavend = fend*4.0 + 4000.0
wave = np.linspace(4000.0, wavend,fend);
# Out:
# 1 spectrum size

# %%
# %matplotlib inline
# %matplotlib nbagg

# %%
plt.plot(wave, fspec)
# Out:
# <img src="data:image/png;base64,...">

# %%
c = 3.0e+18
plt.plot(wave/c, fspec)
# Out:
# <img src="data:image/png;base64,...">
